# %%
# 设置环境变量
import os
# os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"
# 导入库
import torch
import blobfile as bf
import transformer_lens
import sparse_autoencoder
from experiments.utils import update_json_file, update_numpy_file
import pandas as pd
from datetime import datetime

# %%
import numpy as np
import re
# 加载模型
def load_model(model_name, center_writing_weights=False):
    model = transformer_lens.HookedTransformer.from_pretrained(model_name, center_writing_weights=center_writing_weights)
    device = next(model.parameters()).device
    return model, device

# 处理输入
def process_input(model, prompt):
    tokens_id = model.to_tokens(prompt)  # (1, n_tokens)
    tokens_str = model.to_str_tokens(prompt)
    with torch.no_grad():
        logits, activation_cache = model.run_with_cache(tokens_id, remove_batch_dim=True)
    return tokens_id, tokens_str, activation_cache

# 提取激活
def get_activation(activation_cache, layer_index=6, location="resid_post_mlp"):
    transformer_lens_loc = {
        "mlp_post_act": f"blocks.{layer_index}.mlp.hook_post",
        "resid_delta_attn": f"blocks.{layer_index}.hook_attn_out",
        "resid_post_attn": f"blocks.{layer_index}.hook_resid_mid",
        "resid_delta_mlp": f"blocks.{layer_index}.hook_mlp_out",
        "resid_post_mlp": f"blocks.{layer_index}.hook_resid_post",
    }[location]
    return activation_cache[transformer_lens_loc]

# 加载自编码器
def load_autoencoder(location, layer_index, device):
    with bf.BlobFile(sparse_autoencoder.paths.v5_128k(location, layer_index), mode="rb") as f:
        state_dict = torch.load(f)
        autoencoder = sparse_autoencoder.Autoencoder.from_state_dict(state_dict)
        autoencoder.to(device)
    return autoencoder

# 编码和解码激活张量
def encode_decode(autoencoder, input_tensor):
    with torch.no_grad():
        latent_activations, info = autoencoder.encode(input_tensor)
        reconstructed_activations = autoencoder.decode(latent_activations, info)
    return latent_activations, reconstructed_activations

# 计算误差并打印结果
def calculate_normalized_mse(input_tensor, reconstructed_activations):
    normalized_mse = (reconstructed_activations - input_tensor).pow(2).sum(dim=1) / (input_tensor).pow(2).sum(dim=1)
    return normalized_mse

def extract_activations(prompt, tokens, latent_activations, top_k=32, activation_threshold=3):
    activations_dict = {}
    prompt_key = prompt  # 根据需要设置不同的 prompt 标识符

    total_activations_count = 0
    
    # 遍历所有 feature
    for feature_index in range(latent_activations.shape[1]):
        # 获取该 feature 的所有激活值
        feature_activations = latent_activations[:, feature_index]
        
        # 仅提取 top k 非零激活值
        non_zero_activations = feature_activations[(feature_activations != 0) & (feature_activations >= activation_threshold)]
        if non_zero_activations.numel() == 0:
            continue
        top_k_values, top_k_indices = torch.topk(non_zero_activations, min(top_k, non_zero_activations.numel()))

        # 构建特征激活字典
        feature_key = f"Feature {feature_index}"
        activations_dict[feature_key] = {prompt_key: {}}
        for value, index in zip(top_k_values, top_k_indices):
            nonzero_indices = (feature_activations == value).nonzero(as_tuple=True)
            if len(nonzero_indices[0]) == 1:  # 确保只有一个元素
                token_index = nonzero_indices[0].item()
                token = tokens[token_index]
                activations_dict[feature_key][prompt][token] = [f"idx:{token_index}",value.item()]
            else:
                print(f"Skipping ambiguous token index: {nonzero_indices}")

        total_activations_count += len(top_k_values)

    # Print the total number of activations extracted
    print(f"Total activations extracted: {total_activations_count}")

    # Optionally, return the total number of activations
    return activations_dict

# %%
model, device = load_model("gpt2")
layer_index = 6
location = "resid_post_mlp"
autoencoder = load_autoencoder(location, layer_index, device)
# Out:
# Loaded pretrained model gpt2 into HookedTransformer

# %%
today = datetime.today().strftime('%Y-%m-%d')
output_folder = f'output/{today}'
os.makedirs(output_folder, exist_ok=True)

# %%
# 设置路径
prompt_folder_path = 'dataset/prompt_1000_pro_2'
os.makedirs(output_folder, exist_ok=True)
# 遍历所有 .parquet 文件
for file_name in os.listdir(prompt_folder_path):
    count = 1
    if file_name.endswith('.parquet'):
        prompt_file_path = os.path.join(prompt_folder_path, file_name)
        data = pd.read_parquet(prompt_file_path)
        data = data[:50]
        for index, row in data.iterrows():
            print(f"current file: {prompt_file_path}")
            prompt_id = row['prompt_id']
            prompt = row['prompt']
            tokens_id, tokens_str, activation_cache = process_input(model, prompt)
            activation = get_activation(activation_cache, layer_index)
            latent_activations, reconstructed_activations = encode_decode(autoencoder, activation)

            print(latent_activations.shape)
            print(activation.shape)
            print(reconstructed_activations.shape)
            non_zero_count = (latent_activations != 0).sum().item()
            print("Non-zero activation count:", non_zero_count)
            print(f"This is {count}/50 prompt")
            count+=1
            activations_dict = extract_activations(prompt_id, tokens_str, latent_activations, top_k=5)
            
            activations_file_name = file_name.replace('.parquet', '_1000_activation_pro_2_128k.json')
            activations_file_path = os.path.join(output_folder, activations_file_name)
            
            update_json_file(activations_file_path, activations_dict)
# Out:
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([174, 131072])
# torch.Size([174, 768])
# torch.Size([174, 768])
# Non-zero activation count: 5568
# This is 1/50 prompt
# Total activations extracted: 577
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([184, 131072])
# torch.Size([184, 768])
# torch.Size([184, 768])
# Non-zero activation count: 5888
# This is 2/50 prompt
# Total activations extracted: 586
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([225, 131072])
# torch.Size([225, 768])
# torch.Size([225, 768])
# Non-zero activation count: 7200
# This is 3/50 prompt
# Total activations extracted: 693
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([95, 131072])
# torch.Size([95, 768])
# torch.Size([95, 768])
# Non-zero activation count: 3040
# This is 4/50 prompt
# Total activations extracted: 317
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([217, 131072])
# torch.Size([217, 768])
# torch.Size([217, 768])
# Non-zero activation count: 6944
# This is 5/50 prompt
# Total activations extracted: 714
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([262, 131072])
# torch.Size([262, 768])
# torch.Size([262, 768])
# Non-zero activation count: 8384
# This is 6/50 prompt
# Total activations extracted: 828
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([53, 131072])
# torch.Size([53, 768])
# torch.Size([53, 768])
# Non-zero activation count: 1696
# This is 7/50 prompt
# Total activations extracted: 192
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([120, 131072])
# torch.Size([120, 768])
# torch.Size([120, 768])
# Non-zero activation count: 3840
# This is 8/50 prompt
# Total activations extracted: 396
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([87, 131072])
# torch.Size([87, 768])
# torch.Size([87, 768])
# Non-zero activation count: 2784
# This is 9/50 prompt
# Total activations extracted: 310
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([137, 131072])
# torch.Size([137, 768])
# torch.Size([137, 768])
# Non-zero activation count: 4384
# This is 10/50 prompt
# Total activations extracted: 428
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([258, 131072])
# torch.Size([258, 768])
# torch.Size([258, 768])
# Non-zero activation count: 8256
# This is 11/50 prompt
# Total activations extracted: 777
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([134, 131072])
# torch.Size([134, 768])
# torch.Size([134, 768])
# Non-zero activation count: 4288
# This is 12/50 prompt
# Total activations extracted: 443
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([173, 131072])
# torch.Size([173, 768])
# torch.Size([173, 768])
# Non-zero activation count: 5536
# This is 13/50 prompt
# Total activations extracted: 579
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([54, 131072])
# torch.Size([54, 768])
# torch.Size([54, 768])
# Non-zero activation count: 1728
# This is 14/50 prompt
# Total activations extracted: 188
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([133, 131072])
# torch.Size([133, 768])
# torch.Size([133, 768])
# Non-zero activation count: 4256
# This is 15/50 prompt
# Total activations extracted: 409
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([34, 131072])
# torch.Size([34, 768])
# torch.Size([34, 768])
# Non-zero activation count: 1088
# This is 16/50 prompt
# Total activations extracted: 116
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([170, 131072])
# torch.Size([170, 768])
# torch.Size([170, 768])
# Non-zero activation count: 5440
# This is 17/50 prompt
# Total activations extracted: 538
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([73, 131072])
# torch.Size([73, 768])
# torch.Size([73, 768])
# Non-zero activation count: 2336
# This is 18/50 prompt
# Total activations extracted: 245
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([59, 131072])
# torch.Size([59, 768])
# torch.Size([59, 768])
# Non-zero activation count: 1888
# This is 19/50 prompt
# Total activations extracted: 212
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([180, 131072])
# torch.Size([180, 768])
# torch.Size([180, 768])
# Non-zero activation count: 5760
# This is 20/50 prompt
# Total activations extracted: 559
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([163, 131072])
# torch.Size([163, 768])
# torch.Size([163, 768])
# Non-zero activation count: 5216
# This is 21/50 prompt
# Total activations extracted: 530
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([102, 131072])
# torch.Size([102, 768])
# torch.Size([102, 768])
# Non-zero activation count: 3264
# This is 22/50 prompt
# Total activations extracted: 332
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([130, 131072])
# torch.Size([130, 768])
# torch.Size([130, 768])
# Non-zero activation count: 4160
# This is 23/50 prompt
# Total activations extracted: 426
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([122, 131072])
# torch.Size([122, 768])
# torch.Size([122, 768])
# Non-zero activation count: 3904
# This is 24/50 prompt
# Total activations extracted: 412
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([115, 131072])
# torch.Size([115, 768])
# torch.Size([115, 768])
# Non-zero activation count: 3680
# This is 25/50 prompt
# Total activations extracted: 346
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([193, 131072])
# torch.Size([193, 768])
# torch.Size([193, 768])
# Non-zero activation count: 6176
# This is 26/50 prompt
# Total activations extracted: 616
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([53, 131072])
# torch.Size([53, 768])
# torch.Size([53, 768])
# Non-zero activation count: 1696
# This is 27/50 prompt
# Total activations extracted: 185
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([123, 131072])
# torch.Size([123, 768])
# torch.Size([123, 768])
# Non-zero activation count: 3936
# This is 28/50 prompt
# Total activations extracted: 428
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([196, 131072])
# torch.Size([196, 768])
# torch.Size([196, 768])
# Non-zero activation count: 6272
# This is 29/50 prompt
# Total activations extracted: 645
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([54, 131072])
# torch.Size([54, 768])
# torch.Size([54, 768])
# Non-zero activation count: 1728
# This is 30/50 prompt
# Total activations extracted: 194
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([112, 131072])
# torch.Size([112, 768])
# torch.Size([112, 768])
# Non-zero activation count: 3584
# This is 31/50 prompt
# Total activations extracted: 405
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([161, 131072])
# torch.Size([161, 768])
# torch.Size([161, 768])
# Non-zero activation count: 5152
# This is 32/50 prompt
# Total activations extracted: 484
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([141, 131072])
# torch.Size([141, 768])
# torch.Size([141, 768])
# Non-zero activation count: 4512
# This is 33/50 prompt
# Total activations extracted: 419
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([106, 131072])
# torch.Size([106, 768])
# torch.Size([106, 768])
# Non-zero activation count: 3392
# This is 34/50 prompt
# Total activations extracted: 334
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([201, 131072])
# torch.Size([201, 768])
# torch.Size([201, 768])
# Non-zero activation count: 6432
# This is 35/50 prompt
# Total activations extracted: 666
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([139, 131072])
# torch.Size([139, 768])
# torch.Size([139, 768])
# Non-zero activation count: 4448
# This is 36/50 prompt
# Total activations extracted: 447
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([202, 131072])
# torch.Size([202, 768])
# torch.Size([202, 768])
# Non-zero activation count: 6464
# This is 37/50 prompt
# Total activations extracted: 595
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([149, 131072])
# torch.Size([149, 768])
# torch.Size([149, 768])
# Non-zero activation count: 4768
# This is 38/50 prompt
# Total activations extracted: 466
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([126, 131072])
# torch.Size([126, 768])
# torch.Size([126, 768])
# Non-zero activation count: 4032
# This is 39/50 prompt
# Total activations extracted: 396
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([81, 131072])
# torch.Size([81, 768])
# torch.Size([81, 768])
# Non-zero activation count: 2592
# This is 40/50 prompt
# Total activations extracted: 285
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([74, 131072])
# torch.Size([74, 768])
# torch.Size([74, 768])
# Non-zero activation count: 2368
# This is 41/50 prompt
# Total activations extracted: 232
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([72, 131072])
# torch.Size([72, 768])
# torch.Size([72, 768])
# Non-zero activation count: 2304
# This is 42/50 prompt
# Total activations extracted: 271
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([128, 131072])
# torch.Size([128, 768])
# torch.Size([128, 768])
# Non-zero activation count: 4096
# This is 43/50 prompt
# Total activations extracted: 453
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([151, 131072])
# torch.Size([151, 768])
# torch.Size([151, 768])
# Non-zero activation count: 4832
# This is 44/50 prompt
# Total activations extracted: 481
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([88, 131072])
# torch.Size([88, 768])
# torch.Size([88, 768])
# Non-zero activation count: 2816
# This is 45/50 prompt
# Total activations extracted: 329
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([150, 131072])
# torch.Size([150, 768])
# torch.Size([150, 768])
# Non-zero activation count: 4800
# This is 46/50 prompt
# Total activations extracted: 497
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([132, 131072])
# torch.Size([132, 768])
# torch.Size([132, 768])
# Non-zero activation count: 4224
# This is 47/50 prompt
# Total activations extracted: 428
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([185, 131072])
# torch.Size([185, 768])
# torch.Size([185, 768])
# Non-zero activation count: 5920
# This is 48/50 prompt
# Total activations extracted: 593
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([84, 131072])
# torch.Size([84, 768])
# torch.Size([84, 768])
# Non-zero activation count: 2688
# This is 49/50 prompt
# Total activations extracted: 305
# current file: dataset/prompt_1000_pro_2\decision_feeling.parquet
# torch.Size([193, 131072])
# torch.Size([193, 768])
# torch.Size([193, 768])
# Non-zero activation count: 6176
# This is 50/50 prompt
# Total activations extracted: 644
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([149, 131072])
# torch.Size([149, 768])
# torch.Size([149, 768])
# Non-zero activation count: 4768
# This is 1/50 prompt
# Total activations extracted: 486
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([180, 131072])
# torch.Size([180, 768])
# torch.Size([180, 768])
# Non-zero activation count: 5760
# This is 2/50 prompt
# Total activations extracted: 558
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([208, 131072])
# torch.Size([208, 768])
# torch.Size([208, 768])
# Non-zero activation count: 6656
# This is 3/50 prompt
# Total activations extracted: 629
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([91, 131072])
# torch.Size([91, 768])
# torch.Size([91, 768])
# Non-zero activation count: 2912
# This is 4/50 prompt
# Total activations extracted: 297
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([184, 131072])
# torch.Size([184, 768])
# torch.Size([184, 768])
# Non-zero activation count: 5888
# This is 5/50 prompt
# Total activations extracted: 620
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([237, 131072])
# torch.Size([237, 768])
# torch.Size([237, 768])
# Non-zero activation count: 7584
# This is 6/50 prompt
# Total activations extracted: 784
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([48, 131072])
# torch.Size([48, 768])
# torch.Size([48, 768])
# Non-zero activation count: 1536
# This is 7/50 prompt
# Total activations extracted: 173
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([118, 131072])
# torch.Size([118, 768])
# torch.Size([118, 768])
# Non-zero activation count: 3776
# This is 8/50 prompt
# Total activations extracted: 393
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([97, 131072])
# torch.Size([97, 768])
# torch.Size([97, 768])
# Non-zero activation count: 3104
# This is 9/50 prompt
# Total activations extracted: 320
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([139, 131072])
# torch.Size([139, 768])
# torch.Size([139, 768])
# Non-zero activation count: 4448
# This is 10/50 prompt
# Total activations extracted: 427
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([269, 131072])
# torch.Size([269, 768])
# torch.Size([269, 768])
# Non-zero activation count: 8608
# This is 11/50 prompt
# Total activations extracted: 783
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([120, 131072])
# torch.Size([120, 768])
# torch.Size([120, 768])
# Non-zero activation count: 3840
# This is 12/50 prompt
# Total activations extracted: 401
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([138, 131072])
# torch.Size([138, 768])
# torch.Size([138, 768])
# Non-zero activation count: 4416
# This is 13/50 prompt
# Total activations extracted: 471
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([55, 131072])
# torch.Size([55, 768])
# torch.Size([55, 768])
# Non-zero activation count: 1760
# This is 14/50 prompt
# Total activations extracted: 189
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([116, 131072])
# torch.Size([116, 768])
# torch.Size([116, 768])
# Non-zero activation count: 3712
# This is 15/50 prompt
# Total activations extracted: 348
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([35, 131072])
# torch.Size([35, 768])
# torch.Size([35, 768])
# Non-zero activation count: 1120
# This is 16/50 prompt
# Total activations extracted: 129
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([170, 131072])
# torch.Size([170, 768])
# torch.Size([170, 768])
# Non-zero activation count: 5440
# This is 17/50 prompt
# Total activations extracted: 557
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([76, 131072])
# torch.Size([76, 768])
# torch.Size([76, 768])
# Non-zero activation count: 2432
# This is 18/50 prompt
# Total activations extracted: 256
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([58, 131072])
# torch.Size([58, 768])
# torch.Size([58, 768])
# Non-zero activation count: 1856
# This is 19/50 prompt
# Total activations extracted: 214
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([182, 131072])
# torch.Size([182, 768])
# torch.Size([182, 768])
# Non-zero activation count: 5824
# This is 20/50 prompt
# Total activations extracted: 580
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([139, 131072])
# torch.Size([139, 768])
# torch.Size([139, 768])
# Non-zero activation count: 4448
# This is 21/50 prompt
# Total activations extracted: 440
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([71, 131072])
# torch.Size([71, 768])
# torch.Size([71, 768])
# Non-zero activation count: 2272
# This is 22/50 prompt
# Total activations extracted: 231
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([125, 131072])
# torch.Size([125, 768])
# torch.Size([125, 768])
# Non-zero activation count: 4000
# This is 23/50 prompt
# Total activations extracted: 391
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([129, 131072])
# torch.Size([129, 768])
# torch.Size([129, 768])
# Non-zero activation count: 4128
# This is 24/50 prompt
# Total activations extracted: 440
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([113, 131072])
# torch.Size([113, 768])
# torch.Size([113, 768])
# Non-zero activation count: 3616
# This is 25/50 prompt
# Total activations extracted: 352
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([173, 131072])
# torch.Size([173, 768])
# torch.Size([173, 768])
# Non-zero activation count: 5536
# This is 26/50 prompt
# Total activations extracted: 543
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([48, 131072])
# torch.Size([48, 768])
# torch.Size([48, 768])
# Non-zero activation count: 1536
# This is 27/50 prompt
# Total activations extracted: 164
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([122, 131072])
# torch.Size([122, 768])
# torch.Size([122, 768])
# Non-zero activation count: 3904
# This is 28/50 prompt
# Total activations extracted: 423
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([170, 131072])
# torch.Size([170, 768])
# torch.Size([170, 768])
# Non-zero activation count: 5440
# This is 29/50 prompt
# Total activations extracted: 538
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([53, 131072])
# torch.Size([53, 768])
# torch.Size([53, 768])
# Non-zero activation count: 1696
# This is 30/50 prompt
# Total activations extracted: 194
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([100, 131072])
# torch.Size([100, 768])
# torch.Size([100, 768])
# Non-zero activation count: 3200
# This is 31/50 prompt
# Total activations extracted: 381
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([157, 131072])
# torch.Size([157, 768])
# torch.Size([157, 768])
# Non-zero activation count: 5024
# This is 32/50 prompt
# Total activations extracted: 467
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([184, 131072])
# torch.Size([184, 768])
# torch.Size([184, 768])
# Non-zero activation count: 5888
# This is 33/50 prompt
# Total activations extracted: 599
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([101, 131072])
# torch.Size([101, 768])
# torch.Size([101, 768])
# Non-zero activation count: 3232
# This is 34/50 prompt
# Total activations extracted: 341
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([181, 131072])
# torch.Size([181, 768])
# torch.Size([181, 768])
# Non-zero activation count: 5792
# This is 35/50 prompt
# Total activations extracted: 584
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([143, 131072])
# torch.Size([143, 768])
# torch.Size([143, 768])
# Non-zero activation count: 4576
# This is 36/50 prompt
# Total activations extracted: 504
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([154, 131072])
# torch.Size([154, 768])
# torch.Size([154, 768])
# Non-zero activation count: 4928
# This is 37/50 prompt
# Total activations extracted: 517
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([139, 131072])
# torch.Size([139, 768])
# torch.Size([139, 768])
# Non-zero activation count: 4448
# This is 38/50 prompt
# Total activations extracted: 439
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([115, 131072])
# torch.Size([115, 768])
# torch.Size([115, 768])
# Non-zero activation count: 3680
# This is 39/50 prompt
# Total activations extracted: 389
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([74, 131072])
# torch.Size([74, 768])
# torch.Size([74, 768])
# Non-zero activation count: 2368
# This is 40/50 prompt
# Total activations extracted: 268
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([61, 131072])
# torch.Size([61, 768])
# torch.Size([61, 768])
# Non-zero activation count: 1952
# This is 41/50 prompt
# Total activations extracted: 209
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([65, 131072])
# torch.Size([65, 768])
# torch.Size([65, 768])
# Non-zero activation count: 2080
# This is 42/50 prompt
# Total activations extracted: 238
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([111, 131072])
# torch.Size([111, 768])
# torch.Size([111, 768])
# Non-zero activation count: 3552
# This is 43/50 prompt
# Total activations extracted: 370
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([141, 131072])
# torch.Size([141, 768])
# torch.Size([141, 768])
# Non-zero activation count: 4512
# This is 44/50 prompt
# Total activations extracted: 453
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([67, 131072])
# torch.Size([67, 768])
# torch.Size([67, 768])
# Non-zero activation count: 2144
# This is 45/50 prompt
# Total activations extracted: 249
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([144, 131072])
# torch.Size([144, 768])
# torch.Size([144, 768])
# Non-zero activation count: 4608
# This is 46/50 prompt
# Total activations extracted: 495
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([136, 131072])
# torch.Size([136, 768])
# torch.Size([136, 768])
# Non-zero activation count: 4352
# This is 47/50 prompt
# Total activations extracted: 465
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([184, 131072])
# torch.Size([184, 768])
# torch.Size([184, 768])
# Non-zero activation count: 5888
# This is 48/50 prompt
# Total activations extracted: 535
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([89, 131072])
# torch.Size([89, 768])
# torch.Size([89, 768])
# Non-zero activation count: 2848
# This is 49/50 prompt
# Total activations extracted: 306
# current file: dataset/prompt_1000_pro_2\decision_thinking.parquet
# torch.Size([208, 131072])
# torch.Size([208, 768])
# torch.Size([208, 768])
# Non-zero activation count: 6656
# This is 50/50 prompt
# Total activations extracted: 678
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([66, 131072])
# torch.Size([66, 768])
# torch.Size([66, 768])
# Non-zero activation count: 2112
# This is 1/50 prompt
# Total activations extracted: 247
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([93, 131072])
# torch.Size([93, 768])
# torch.Size([93, 768])
# Non-zero activation count: 2976
# This is 2/50 prompt
# Total activations extracted: 311
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([130, 131072])
# torch.Size([130, 768])
# torch.Size([130, 768])
# Non-zero activation count: 4160
# This is 3/50 prompt
# Total activations extracted: 437
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([151, 131072])
# torch.Size([151, 768])
# torch.Size([151, 768])
# Non-zero activation count: 4832
# This is 4/50 prompt
# Total activations extracted: 497
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([138, 131072])
# torch.Size([138, 768])
# torch.Size([138, 768])
# Non-zero activation count: 4416
# This is 5/50 prompt
# Total activations extracted: 443
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([77, 131072])
# torch.Size([77, 768])
# torch.Size([77, 768])
# Non-zero activation count: 2464
# This is 6/50 prompt
# Total activations extracted: 271
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([129, 131072])
# torch.Size([129, 768])
# torch.Size([129, 768])
# Non-zero activation count: 4128
# This is 7/50 prompt
# Total activations extracted: 440
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([117, 131072])
# torch.Size([117, 768])
# torch.Size([117, 768])
# Non-zero activation count: 3744
# This is 8/50 prompt
# Total activations extracted: 364
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([115, 131072])
# torch.Size([115, 768])
# torch.Size([115, 768])
# Non-zero activation count: 3680
# This is 9/50 prompt
# Total activations extracted: 444
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([81, 131072])
# torch.Size([81, 768])
# torch.Size([81, 768])
# Non-zero activation count: 2592
# This is 10/50 prompt
# Total activations extracted: 301
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([104, 131072])
# torch.Size([104, 768])
# torch.Size([104, 768])
# Non-zero activation count: 3328
# This is 11/50 prompt
# Total activations extracted: 356
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([140, 131072])
# torch.Size([140, 768])
# torch.Size([140, 768])
# Non-zero activation count: 4480
# This is 12/50 prompt
# Total activations extracted: 467
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([187, 131072])
# torch.Size([187, 768])
# torch.Size([187, 768])
# Non-zero activation count: 5984
# This is 13/50 prompt
# Total activations extracted: 630
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([150, 131072])
# torch.Size([150, 768])
# torch.Size([150, 768])
# Non-zero activation count: 4800
# This is 14/50 prompt
# Total activations extracted: 515
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([142, 131072])
# torch.Size([142, 768])
# torch.Size([142, 768])
# Non-zero activation count: 4544
# This is 15/50 prompt
# Total activations extracted: 483
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([42, 131072])
# torch.Size([42, 768])
# torch.Size([42, 768])
# Non-zero activation count: 1344
# This is 16/50 prompt
# Total activations extracted: 163
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([115, 131072])
# torch.Size([115, 768])
# torch.Size([115, 768])
# Non-zero activation count: 3680
# This is 17/50 prompt
# Total activations extracted: 354
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([148, 131072])
# torch.Size([148, 768])
# torch.Size([148, 768])
# Non-zero activation count: 4736
# This is 18/50 prompt
# Total activations extracted: 486
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([131, 131072])
# torch.Size([131, 768])
# torch.Size([131, 768])
# Non-zero activation count: 4192
# This is 19/50 prompt
# Total activations extracted: 408
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([126, 131072])
# torch.Size([126, 768])
# torch.Size([126, 768])
# Non-zero activation count: 4032
# This is 20/50 prompt
# Total activations extracted: 448
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([163, 131072])
# torch.Size([163, 768])
# torch.Size([163, 768])
# Non-zero activation count: 5216
# This is 21/50 prompt
# Total activations extracted: 507
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([102, 131072])
# torch.Size([102, 768])
# torch.Size([102, 768])
# Non-zero activation count: 3264
# This is 22/50 prompt
# Total activations extracted: 348
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([79, 131072])
# torch.Size([79, 768])
# torch.Size([79, 768])
# Non-zero activation count: 2528
# This is 23/50 prompt
# Total activations extracted: 288
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([198, 131072])
# torch.Size([198, 768])
# torch.Size([198, 768])
# Non-zero activation count: 6336
# This is 24/50 prompt
# Total activations extracted: 736
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([162, 131072])
# torch.Size([162, 768])
# torch.Size([162, 768])
# Non-zero activation count: 5184
# This is 25/50 prompt
# Total activations extracted: 536
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([125, 131072])
# torch.Size([125, 768])
# torch.Size([125, 768])
# Non-zero activation count: 4000
# This is 26/50 prompt
# Total activations extracted: 407
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([38, 131072])
# torch.Size([38, 768])
# torch.Size([38, 768])
# Non-zero activation count: 1216
# This is 27/50 prompt
# Total activations extracted: 131
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([161, 131072])
# torch.Size([161, 768])
# torch.Size([161, 768])
# Non-zero activation count: 5152
# This is 28/50 prompt
# Total activations extracted: 570
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([108, 131072])
# torch.Size([108, 768])
# torch.Size([108, 768])
# Non-zero activation count: 3456
# This is 29/50 prompt
# Total activations extracted: 341
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([88, 131072])
# torch.Size([88, 768])
# torch.Size([88, 768])
# Non-zero activation count: 2816
# This is 30/50 prompt
# Total activations extracted: 323
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([82, 131072])
# torch.Size([82, 768])
# torch.Size([82, 768])
# Non-zero activation count: 2624
# This is 31/50 prompt
# Total activations extracted: 280
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([72, 131072])
# torch.Size([72, 768])
# torch.Size([72, 768])
# Non-zero activation count: 2304
# This is 32/50 prompt
# Total activations extracted: 274
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([46, 131072])
# torch.Size([46, 768])
# torch.Size([46, 768])
# Non-zero activation count: 1472
# This is 33/50 prompt
# Total activations extracted: 159
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([102, 131072])
# torch.Size([102, 768])
# torch.Size([102, 768])
# Non-zero activation count: 3264
# This is 34/50 prompt
# Total activations extracted: 416
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([110, 131072])
# torch.Size([110, 768])
# torch.Size([110, 768])
# Non-zero activation count: 3520
# This is 35/50 prompt
# Total activations extracted: 383
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([163, 131072])
# torch.Size([163, 768])
# torch.Size([163, 768])
# Non-zero activation count: 5216
# This is 36/50 prompt
# Total activations extracted: 566
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([110, 131072])
# torch.Size([110, 768])
# torch.Size([110, 768])
# Non-zero activation count: 3520
# This is 37/50 prompt
# Total activations extracted: 365
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([162, 131072])
# torch.Size([162, 768])
# torch.Size([162, 768])
# Non-zero activation count: 5184
# This is 38/50 prompt
# Total activations extracted: 518
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([48, 131072])
# torch.Size([48, 768])
# torch.Size([48, 768])
# Non-zero activation count: 1536
# This is 39/50 prompt
# Total activations extracted: 175
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([44, 131072])
# torch.Size([44, 768])
# torch.Size([44, 768])
# Non-zero activation count: 1408
# This is 40/50 prompt
# Total activations extracted: 162
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([164, 131072])
# torch.Size([164, 768])
# torch.Size([164, 768])
# Non-zero activation count: 5248
# This is 41/50 prompt
# Total activations extracted: 553
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([131, 131072])
# torch.Size([131, 768])
# torch.Size([131, 768])
# Non-zero activation count: 4192
# This is 42/50 prompt
# Total activations extracted: 463
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([127, 131072])
# torch.Size([127, 768])
# torch.Size([127, 768])
# Non-zero activation count: 4064
# This is 43/50 prompt
# Total activations extracted: 417
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([120, 131072])
# torch.Size([120, 768])
# torch.Size([120, 768])
# Non-zero activation count: 3840
# This is 44/50 prompt
# Total activations extracted: 404
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([127, 131072])
# torch.Size([127, 768])
# torch.Size([127, 768])
# Non-zero activation count: 4064
# This is 45/50 prompt
# Total activations extracted: 436
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([113, 131072])
# torch.Size([113, 768])
# torch.Size([113, 768])
# Non-zero activation count: 3616
# This is 46/50 prompt
# Total activations extracted: 360
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([72, 131072])
# torch.Size([72, 768])
# torch.Size([72, 768])
# Non-zero activation count: 2304
# This is 47/50 prompt
# Total activations extracted: 254
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([43, 131072])
# torch.Size([43, 768])
# torch.Size([43, 768])
# Non-zero activation count: 1376
# This is 48/50 prompt
# Total activations extracted: 142
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([53, 131072])
# torch.Size([53, 768])
# torch.Size([53, 768])
# Non-zero activation count: 1696
# This is 49/50 prompt
# Total activations extracted: 194
# current file: dataset/prompt_1000_pro_2\energy_extraversion.parquet
# torch.Size([79, 131072])
# torch.Size([79, 768])
# torch.Size([79, 768])
# Non-zero activation count: 2528
# This is 50/50 prompt
# Total activations extracted: 284
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([58, 131072])
# torch.Size([58, 768])
# torch.Size([58, 768])
# Non-zero activation count: 1856
# This is 1/50 prompt
# Total activations extracted: 212
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([95, 131072])
# torch.Size([95, 768])
# torch.Size([95, 768])
# Non-zero activation count: 3040
# This is 2/50 prompt
# Total activations extracted: 325
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([123, 131072])
# torch.Size([123, 768])
# torch.Size([123, 768])
# Non-zero activation count: 3936
# This is 3/50 prompt
# Total activations extracted: 420
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([136, 131072])
# torch.Size([136, 768])
# torch.Size([136, 768])
# Non-zero activation count: 4352
# This is 4/50 prompt
# Total activations extracted: 454
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([139, 131072])
# torch.Size([139, 768])
# torch.Size([139, 768])
# Non-zero activation count: 4448
# This is 5/50 prompt
# Total activations extracted: 442
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([75, 131072])
# torch.Size([75, 768])
# torch.Size([75, 768])
# Non-zero activation count: 2400
# This is 6/50 prompt
# Total activations extracted: 260
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([130, 131072])
# torch.Size([130, 768])
# torch.Size([130, 768])
# Non-zero activation count: 4160
# This is 7/50 prompt
# Total activations extracted: 441
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([111, 131072])
# torch.Size([111, 768])
# torch.Size([111, 768])
# Non-zero activation count: 3552
# This is 8/50 prompt
# Total activations extracted: 347
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([132, 131072])
# torch.Size([132, 768])
# torch.Size([132, 768])
# Non-zero activation count: 4224
# This is 9/50 prompt
# Total activations extracted: 482
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([83, 131072])
# torch.Size([83, 768])
# torch.Size([83, 768])
# Non-zero activation count: 2656
# This is 10/50 prompt
# Total activations extracted: 305
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([101, 131072])
# torch.Size([101, 768])
# torch.Size([101, 768])
# Non-zero activation count: 3232
# This is 11/50 prompt
# Total activations extracted: 336
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([135, 131072])
# torch.Size([135, 768])
# torch.Size([135, 768])
# Non-zero activation count: 4320
# This is 12/50 prompt
# Total activations extracted: 480
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([194, 131072])
# torch.Size([194, 768])
# torch.Size([194, 768])
# Non-zero activation count: 6208
# This is 13/50 prompt
# Total activations extracted: 615
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([168, 131072])
# torch.Size([168, 768])
# torch.Size([168, 768])
# Non-zero activation count: 5376
# This is 14/50 prompt
# Total activations extracted: 575
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([150, 131072])
# torch.Size([150, 768])
# torch.Size([150, 768])
# Non-zero activation count: 4800
# This is 15/50 prompt
# Total activations extracted: 465
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([46, 131072])
# torch.Size([46, 768])
# torch.Size([46, 768])
# Non-zero activation count: 1472
# This is 16/50 prompt
# Total activations extracted: 168
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([130, 131072])
# torch.Size([130, 768])
# torch.Size([130, 768])
# Non-zero activation count: 4160
# This is 17/50 prompt
# Total activations extracted: 396
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([146, 131072])
# torch.Size([146, 768])
# torch.Size([146, 768])
# Non-zero activation count: 4672
# This is 18/50 prompt
# Total activations extracted: 482
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([131, 131072])
# torch.Size([131, 768])
# torch.Size([131, 768])
# Non-zero activation count: 4192
# This is 19/50 prompt
# Total activations extracted: 410
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([127, 131072])
# torch.Size([127, 768])
# torch.Size([127, 768])
# Non-zero activation count: 4064
# This is 20/50 prompt
# Total activations extracted: 446
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([143, 131072])
# torch.Size([143, 768])
# torch.Size([143, 768])
# Non-zero activation count: 4576
# This is 21/50 prompt
# Total activations extracted: 459
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([112, 131072])
# torch.Size([112, 768])
# torch.Size([112, 768])
# Non-zero activation count: 3584
# This is 22/50 prompt
# Total activations extracted: 386
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([86, 131072])
# torch.Size([86, 768])
# torch.Size([86, 768])
# Non-zero activation count: 2752
# This is 23/50 prompt
# Total activations extracted: 319
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([205, 131072])
# torch.Size([205, 768])
# torch.Size([205, 768])
# Non-zero activation count: 6560
# This is 24/50 prompt
# Total activations extracted: 703
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([167, 131072])
# torch.Size([167, 768])
# torch.Size([167, 768])
# Non-zero activation count: 5344
# This is 25/50 prompt
# Total activations extracted: 529
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([149, 131072])
# torch.Size([149, 768])
# torch.Size([149, 768])
# Non-zero activation count: 4768
# This is 26/50 prompt
# Total activations extracted: 506
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([37, 131072])
# torch.Size([37, 768])
# torch.Size([37, 768])
# Non-zero activation count: 1184
# This is 27/50 prompt
# Total activations extracted: 127
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([150, 131072])
# torch.Size([150, 768])
# torch.Size([150, 768])
# Non-zero activation count: 4800
# This is 28/50 prompt
# Total activations extracted: 500
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([124, 131072])
# torch.Size([124, 768])
# torch.Size([124, 768])
# Non-zero activation count: 3968
# This is 29/50 prompt
# Total activations extracted: 401
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([86, 131072])
# torch.Size([86, 768])
# torch.Size([86, 768])
# Non-zero activation count: 2752
# This is 30/50 prompt
# Total activations extracted: 314
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([91, 131072])
# torch.Size([91, 768])
# torch.Size([91, 768])
# Non-zero activation count: 2912
# This is 31/50 prompt
# Total activations extracted: 307
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([77, 131072])
# torch.Size([77, 768])
# torch.Size([77, 768])
# Non-zero activation count: 2464
# This is 32/50 prompt
# Total activations extracted: 281
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([45, 131072])
# torch.Size([45, 768])
# torch.Size([45, 768])
# Non-zero activation count: 1440
# This is 33/50 prompt
# Total activations extracted: 144
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([105, 131072])
# torch.Size([105, 768])
# torch.Size([105, 768])
# Non-zero activation count: 3360
# This is 34/50 prompt
# Total activations extracted: 413
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([115, 131072])
# torch.Size([115, 768])
# torch.Size([115, 768])
# Non-zero activation count: 3680
# This is 35/50 prompt
# Total activations extracted: 382
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([156, 131072])
# torch.Size([156, 768])
# torch.Size([156, 768])
# Non-zero activation count: 4992
# This is 36/50 prompt
# Total activations extracted: 533
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([53, 131072])
# torch.Size([53, 768])
# torch.Size([53, 768])
# Non-zero activation count: 1696
# This is 37/50 prompt
# Total activations extracted: 184
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([167, 131072])
# torch.Size([167, 768])
# torch.Size([167, 768])
# Non-zero activation count: 5344
# This is 38/50 prompt
# Total activations extracted: 525
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([47, 131072])
# torch.Size([47, 768])
# torch.Size([47, 768])
# Non-zero activation count: 1504
# This is 39/50 prompt
# Total activations extracted: 163
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([48, 131072])
# torch.Size([48, 768])
# torch.Size([48, 768])
# Non-zero activation count: 1536
# This is 40/50 prompt
# Total activations extracted: 173
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([168, 131072])
# torch.Size([168, 768])
# torch.Size([168, 768])
# Non-zero activation count: 5376
# This is 41/50 prompt
# Total activations extracted: 571
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([151, 131072])
# torch.Size([151, 768])
# torch.Size([151, 768])
# Non-zero activation count: 4832
# This is 42/50 prompt
# Total activations extracted: 533
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([128, 131072])
# torch.Size([128, 768])
# torch.Size([128, 768])
# Non-zero activation count: 4096
# This is 43/50 prompt
# Total activations extracted: 429
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([132, 131072])
# torch.Size([132, 768])
# torch.Size([132, 768])
# Non-zero activation count: 4224
# This is 44/50 prompt
# Total activations extracted: 453
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([135, 131072])
# torch.Size([135, 768])
# torch.Size([135, 768])
# Non-zero activation count: 4320
# This is 45/50 prompt
# Total activations extracted: 454
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([112, 131072])
# torch.Size([112, 768])
# torch.Size([112, 768])
# Non-zero activation count: 3584
# This is 46/50 prompt
# Total activations extracted: 373
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([70, 131072])
# torch.Size([70, 768])
# torch.Size([70, 768])
# Non-zero activation count: 2240
# This is 47/50 prompt
# Total activations extracted: 249
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([42, 131072])
# torch.Size([42, 768])
# torch.Size([42, 768])
# Non-zero activation count: 1344
# This is 48/50 prompt
# Total activations extracted: 141
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([54, 131072])
# torch.Size([54, 768])
# torch.Size([54, 768])
# Non-zero activation count: 1728
# This is 49/50 prompt
# Total activations extracted: 200
# current file: dataset/prompt_1000_pro_2\energy_introversion.parquet
# torch.Size([79, 131072])
# torch.Size([79, 768])
# torch.Size([79, 768])
# Non-zero activation count: 2528
# This is 50/50 prompt
# Total activations extracted: 285
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([112, 131072])
# torch.Size([112, 768])
# torch.Size([112, 768])
# Non-zero activation count: 3584
# This is 1/50 prompt
# Total activations extracted: 363
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([90, 131072])
# torch.Size([90, 768])
# torch.Size([90, 768])
# Non-zero activation count: 2880
# This is 2/50 prompt
# Total activations extracted: 311
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([154, 131072])
# torch.Size([154, 768])
# torch.Size([154, 768])
# Non-zero activation count: 4928
# This is 3/50 prompt
# Total activations extracted: 558
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([133, 131072])
# torch.Size([133, 768])
# torch.Size([133, 768])
# Non-zero activation count: 4256
# This is 4/50 prompt
# Total activations extracted: 473
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([126, 131072])
# torch.Size([126, 768])
# torch.Size([126, 768])
# Non-zero activation count: 4032
# This is 5/50 prompt
# Total activations extracted: 423
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([49, 131072])
# torch.Size([49, 768])
# torch.Size([49, 768])
# Non-zero activation count: 1568
# This is 6/50 prompt
# Total activations extracted: 176
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([173, 131072])
# torch.Size([173, 768])
# torch.Size([173, 768])
# Non-zero activation count: 5536
# This is 7/50 prompt
# Total activations extracted: 513
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([197, 131072])
# torch.Size([197, 768])
# torch.Size([197, 768])
# Non-zero activation count: 6304
# This is 8/50 prompt
# Total activations extracted: 553
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([195, 131072])
# torch.Size([195, 768])
# torch.Size([195, 768])
# Non-zero activation count: 6240
# This is 9/50 prompt
# Total activations extracted: 582
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([162, 131072])
# torch.Size([162, 768])
# torch.Size([162, 768])
# Non-zero activation count: 5184
# This is 10/50 prompt
# Total activations extracted: 517
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([98, 131072])
# torch.Size([98, 768])
# torch.Size([98, 768])
# Non-zero activation count: 3136
# This is 11/50 prompt
# Total activations extracted: 311
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([145, 131072])
# torch.Size([145, 768])
# torch.Size([145, 768])
# Non-zero activation count: 4640
# This is 12/50 prompt
# Total activations extracted: 442
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([112, 131072])
# torch.Size([112, 768])
# torch.Size([112, 768])
# Non-zero activation count: 3584
# This is 13/50 prompt
# Total activations extracted: 380
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([47, 131072])
# torch.Size([47, 768])
# torch.Size([47, 768])
# Non-zero activation count: 1504
# This is 14/50 prompt
# Total activations extracted: 148
# current file: dataset/prompt_1000_pro_2\execution_judging.parquet
# torch.Size([64, 131072])
# torch.Size([64, 768])
# torch.Size([64, 768])
# ...
# torch.Size([72, 131072])
# torch.Size([72, 768])
# torch.Size([72, 768])
# Non-zero activation count: 2304
# This is 30/50 prompt
# Total activations extracted: 269
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([126, 131072])
# torch.Size([126, 768])
# torch.Size([126, 768])
# Non-zero activation count: 4032
# This is 31/50 prompt
# Total activations extracted: 398
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([99, 131072])
# torch.Size([99, 768])
# torch.Size([99, 768])
# Non-zero activation count: 3168
# This is 32/50 prompt
# Total activations extracted: 363
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([36, 131072])
# torch.Size([36, 768])
# torch.Size([36, 768])
# Non-zero activation count: 1152
# This is 33/50 prompt
# Total activations extracted: 133
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([143, 131072])
# torch.Size([143, 768])
# torch.Size([143, 768])
# Non-zero activation count: 4576
# This is 34/50 prompt
# Total activations extracted: 463
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([111, 131072])
# torch.Size([111, 768])
# torch.Size([111, 768])
# Non-zero activation count: 3552
# This is 35/50 prompt
# Total activations extracted: 377
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([148, 131072])
# torch.Size([148, 768])
# torch.Size([148, 768])
# Non-zero activation count: 4736
# This is 36/50 prompt
# Total activations extracted: 477
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([144, 131072])
# torch.Size([144, 768])
# torch.Size([144, 768])
# Non-zero activation count: 4608
# This is 37/50 prompt
# Total activations extracted: 471
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([102, 131072])
# torch.Size([102, 768])
# torch.Size([102, 768])
# Non-zero activation count: 3264
# This is 38/50 prompt
# Total activations extracted: 358
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([136, 131072])
# torch.Size([136, 768])
# torch.Size([136, 768])
# Non-zero activation count: 4352
# This is 39/50 prompt
# Total activations extracted: 504
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([144, 131072])
# torch.Size([144, 768])
# torch.Size([144, 768])
# Non-zero activation count: 4608
# This is 40/50 prompt
# Total activations extracted: 463
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([145, 131072])
# torch.Size([145, 768])
# torch.Size([145, 768])
# Non-zero activation count: 4640
# This is 41/50 prompt
# Total activations extracted: 565
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([178, 131072])
# torch.Size([178, 768])
# torch.Size([178, 768])
# Non-zero activation count: 5696
# This is 42/50 prompt
# Total activations extracted: 564
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([146, 131072])
# torch.Size([146, 768])
# torch.Size([146, 768])
# Non-zero activation count: 4672
# This is 43/50 prompt
# Total activations extracted: 462
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([197, 131072])
# torch.Size([197, 768])
# torch.Size([197, 768])
# Non-zero activation count: 6304
# This is 44/50 prompt
# Total activations extracted: 656
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([107, 131072])
# torch.Size([107, 768])
# torch.Size([107, 768])
# Non-zero activation count: 3424
# This is 45/50 prompt
# Total activations extracted: 326
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([134, 131072])
# torch.Size([134, 768])
# torch.Size([134, 768])
# Non-zero activation count: 4288
# This is 46/50 prompt
# Total activations extracted: 423
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([101, 131072])
# torch.Size([101, 768])
# torch.Size([101, 768])
# Non-zero activation count: 3232
# This is 47/50 prompt
# Total activations extracted: 349
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([147, 131072])
# torch.Size([147, 768])
# torch.Size([147, 768])
# Non-zero activation count: 4704
# This is 48/50 prompt
# Total activations extracted: 481
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([36, 131072])
# torch.Size([36, 768])
# torch.Size([36, 768])
# Non-zero activation count: 1152
# This is 49/50 prompt
# Total activations extracted: 130
# current file: dataset/prompt_1000_pro_2\information_intuition.parquet
# torch.Size([128, 131072])
# torch.Size([128, 768])
# torch.Size([128, 768])
# Non-zero activation count: 4096
# This is 50/50 prompt
# Total activations extracted: 413
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([142, 131072])
# torch.Size([142, 768])
# torch.Size([142, 768])
# Non-zero activation count: 4544
# This is 1/50 prompt
# Total activations extracted: 460
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([126, 131072])
# torch.Size([126, 768])
# torch.Size([126, 768])
# Non-zero activation count: 4032
# This is 2/50 prompt
# Total activations extracted: 422
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([127, 131072])
# torch.Size([127, 768])
# torch.Size([127, 768])
# Non-zero activation count: 4064
# This is 3/50 prompt
# Total activations extracted: 397
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([137, 131072])
# torch.Size([137, 768])
# torch.Size([137, 768])
# Non-zero activation count: 4384
# This is 4/50 prompt
# Total activations extracted: 462
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([43, 131072])
# torch.Size([43, 768])
# torch.Size([43, 768])
# Non-zero activation count: 1376
# This is 5/50 prompt
# Total activations extracted: 160
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([177, 131072])
# torch.Size([177, 768])
# torch.Size([177, 768])
# Non-zero activation count: 5664
# This is 6/50 prompt
# Total activations extracted: 613
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([98, 131072])
# torch.Size([98, 768])
# torch.Size([98, 768])
# Non-zero activation count: 3136
# This is 7/50 prompt
# Total activations extracted: 369
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([94, 131072])
# torch.Size([94, 768])
# torch.Size([94, 768])
# Non-zero activation count: 3008
# This is 8/50 prompt
# Total activations extracted: 301
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([104, 131072])
# torch.Size([104, 768])
# torch.Size([104, 768])
# Non-zero activation count: 3328
# This is 9/50 prompt
# Total activations extracted: 336
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([96, 131072])
# torch.Size([96, 768])
# torch.Size([96, 768])
# Non-zero activation count: 3072
# This is 10/50 prompt
# Total activations extracted: 308
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([38, 131072])
# torch.Size([38, 768])
# torch.Size([38, 768])
# Non-zero activation count: 1216
# This is 11/50 prompt
# Total activations extracted: 132
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([141, 131072])
# torch.Size([141, 768])
# torch.Size([141, 768])
# Non-zero activation count: 4512
# This is 12/50 prompt
# Total activations extracted: 471
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([152, 131072])
# torch.Size([152, 768])
# torch.Size([152, 768])
# Non-zero activation count: 4864
# This is 13/50 prompt
# Total activations extracted: 500
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([117, 131072])
# torch.Size([117, 768])
# torch.Size([117, 768])
# Non-zero activation count: 3744
# This is 14/50 prompt
# Total activations extracted: 424
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([130, 131072])
# torch.Size([130, 768])
# torch.Size([130, 768])
# Non-zero activation count: 4160
# This is 15/50 prompt
# Total activations extracted: 442
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([101, 131072])
# torch.Size([101, 768])
# torch.Size([101, 768])
# Non-zero activation count: 3232
# This is 16/50 prompt
# Total activations extracted: 336
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([152, 131072])
# torch.Size([152, 768])
# torch.Size([152, 768])
# Non-zero activation count: 4864
# This is 17/50 prompt
# Total activations extracted: 486
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([178, 131072])
# torch.Size([178, 768])
# torch.Size([178, 768])
# Non-zero activation count: 5696
# This is 18/50 prompt
# Total activations extracted: 587
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([66, 131072])
# torch.Size([66, 768])
# torch.Size([66, 768])
# Non-zero activation count: 2112
# This is 19/50 prompt
# Total activations extracted: 234
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([125, 131072])
# torch.Size([125, 768])
# torch.Size([125, 768])
# Non-zero activation count: 4000
# This is 20/50 prompt
# Total activations extracted: 398
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([107, 131072])
# torch.Size([107, 768])
# torch.Size([107, 768])
# Non-zero activation count: 3424
# This is 21/50 prompt
# Total activations extracted: 331
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([134, 131072])
# torch.Size([134, 768])
# torch.Size([134, 768])
# Non-zero activation count: 4288
# This is 22/50 prompt
# Total activations extracted: 437
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([150, 131072])
# torch.Size([150, 768])
# torch.Size([150, 768])
# Non-zero activation count: 4800
# This is 23/50 prompt
# Total activations extracted: 493
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([225, 131072])
# torch.Size([225, 768])
# torch.Size([225, 768])
# Non-zero activation count: 7200
# This is 24/50 prompt
# Total activations extracted: 749
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([255, 131072])
# torch.Size([255, 768])
# torch.Size([255, 768])
# Non-zero activation count: 8160
# This is 25/50 prompt
# Total activations extracted: 703
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([95, 131072])
# torch.Size([95, 768])
# torch.Size([95, 768])
# Non-zero activation count: 3040
# This is 26/50 prompt
# Total activations extracted: 329
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([42, 131072])
# torch.Size([42, 768])
# torch.Size([42, 768])
# Non-zero activation count: 1344
# This is 27/50 prompt
# Total activations extracted: 154
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([246, 131072])
# torch.Size([246, 768])
# torch.Size([246, 768])
# Non-zero activation count: 7872
# This is 28/50 prompt
# Total activations extracted: 730
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([107, 131072])
# torch.Size([107, 768])
# torch.Size([107, 768])
# Non-zero activation count: 3424
# This is 29/50 prompt
# Total activations extracted: 368
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([72, 131072])
# torch.Size([72, 768])
# torch.Size([72, 768])
# Non-zero activation count: 2304
# This is 30/50 prompt
# Total activations extracted: 265
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([107, 131072])
# torch.Size([107, 768])
# torch.Size([107, 768])
# Non-zero activation count: 3424
# This is 31/50 prompt
# Total activations extracted: 343
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([109, 131072])
# torch.Size([109, 768])
# torch.Size([109, 768])
# Non-zero activation count: 3488
# This is 32/50 prompt
# Total activations extracted: 397
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([38, 131072])
# torch.Size([38, 768])
# torch.Size([38, 768])
# Non-zero activation count: 1216
# This is 33/50 prompt
# Total activations extracted: 145
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([158, 131072])
# torch.Size([158, 768])
# torch.Size([158, 768])
# Non-zero activation count: 5056
# This is 34/50 prompt
# Total activations extracted: 544
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([102, 131072])
# torch.Size([102, 768])
# torch.Size([102, 768])
# Non-zero activation count: 3264
# This is 35/50 prompt
# Total activations extracted: 330
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([130, 131072])
# torch.Size([130, 768])
# torch.Size([130, 768])
# Non-zero activation count: 4160
# This is 36/50 prompt
# Total activations extracted: 398
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([122, 131072])
# torch.Size([122, 768])
# torch.Size([122, 768])
# Non-zero activation count: 3904
# This is 37/50 prompt
# Total activations extracted: 413
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([41, 131072])
# torch.Size([41, 768])
# torch.Size([41, 768])
# Non-zero activation count: 1312
# This is 38/50 prompt
# Total activations extracted: 154
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([114, 131072])
# torch.Size([114, 768])
# torch.Size([114, 768])
# Non-zero activation count: 3648
# This is 39/50 prompt
# Total activations extracted: 397
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([146, 131072])
# torch.Size([146, 768])
# torch.Size([146, 768])
# Non-zero activation count: 4672
# This is 40/50 prompt
# Total activations extracted: 472
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([132, 131072])
# torch.Size([132, 768])
# torch.Size([132, 768])
# Non-zero activation count: 4224
# This is 41/50 prompt
# Total activations extracted: 499
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([187, 131072])
# torch.Size([187, 768])
# torch.Size([187, 768])
# Non-zero activation count: 5984
# This is 42/50 prompt
# Total activations extracted: 594
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([135, 131072])
# torch.Size([135, 768])
# torch.Size([135, 768])
# Non-zero activation count: 4320
# This is 43/50 prompt
# Total activations extracted: 433
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([170, 131072])
# torch.Size([170, 768])
# torch.Size([170, 768])
# Non-zero activation count: 5440
# This is 44/50 prompt
# Total activations extracted: 571
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([104, 131072])
# torch.Size([104, 768])
# torch.Size([104, 768])
# Non-zero activation count: 3328
# This is 45/50 prompt
# Total activations extracted: 318
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([123, 131072])
# torch.Size([123, 768])
# torch.Size([123, 768])
# Non-zero activation count: 3936
# This is 46/50 prompt
# Total activations extracted: 395
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([79, 131072])
# torch.Size([79, 768])
# torch.Size([79, 768])
# Non-zero activation count: 2528
# This is 47/50 prompt
# Total activations extracted: 284
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([154, 131072])
# torch.Size([154, 768])
# torch.Size([154, 768])
# Non-zero activation count: 4928
# This is 48/50 prompt
# Total activations extracted: 488
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([36, 131072])
# torch.Size([36, 768])
# torch.Size([36, 768])
# Non-zero activation count: 1152
# This is 49/50 prompt
# Total activations extracted: 128
# current file: dataset/prompt_1000_pro_2\information_sensing.parquet
# torch.Size([137, 131072])
# torch.Size([137, 768])
# torch.Size([137, 768])
# Non-zero activation count: 4384
# This is 50/50 prompt
# Total activations extracted: 434

# %%
prompt = 'Pretend you’re a perceiving person to answer the question.'
tokens_id, tokens_str, activation_cache = process_input(model, prompt)
tokens_str
# Out:
# ['<|endoftext|>',
#  'P',
#  'ret',
#  'end',
#  ' you',
#  '�',
#  '�',
#  're',
#  ' a',
#  ' perce',
#  'iving',
#  ' person',
#  ' to',
#  ' answer',
#  ' the',
#  ' question',
#  '.']
